# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in /Users/user/micromamba/lib/python3.9/site-packages (8.2.54)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (1.26.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (3.8.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (2.2.0)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/user/micromamba/lib/python3.9/site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/user/micromamba/lib/python3.9/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/user/micromamba/lib/python3.9/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/user/micromamba/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/user/micromamba/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/user/micromamba/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/user/micromamba/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /Users/user/micromamba/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/user/micromamba/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /Users/user/micromamba/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /Users/user/micromamba/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/user/micromamba/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /Users/user/micromamba/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (2023.12.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/user/micromamba/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/user/micromamba/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/user/micromamba/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /Users/user/micromamba/lib/python3.9/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Collecting roboflow
#   Downloading roboflow-1.1.34-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: certifi in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (2023.11.17)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (3.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (1.26.3)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (10.2.0)
# Requirement already satisfied: python-dateutil in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (2.1.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: python-magic in /Users/user/micromamba/lib/python3.9/site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib->roboflow) (4.47.2)
# Requirement already satisfied: packaging>=20.0 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib->roboflow) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/user/micromamba/lib/python3.9/site-packages (from matplotlib->roboflow) (6.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/user/micromamba/lib/python3.9/site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/user/micromamba/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.17.0)
# Downloading roboflow-1.1.34-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 7.0 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.8 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 10.6 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 40.0 MB/s eta 0:00:0000:0100:01
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: opencv-python-headless, idna, chardet, requests-toolbelt, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# Successfully installed chardet-4.0.0 idna-3.7 opencv-python-headless-4.10.0.84 requests-toolbelt-1.0.0 roboflow-1.1.34

# %%
pip install roboflow
# Out:
# Collecting roboflow
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/eb/d5/97888f43bec54450561e4a6a111da7bd5f55ae9b02424a7310c17f4c33ed/roboflow-1.1.34-py3-none-any.whl.metadata
#   Downloading roboflow-1.1.34-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (2024.7.4)
# Collecting chardet==4.0.0 (from roboflow)
#   Obtaining dependency information for chardet==4.0.0 from https://files.pythonhosted.org/packages/19/c7/fa589626997dd07bd87d9269342ccb74b1720384a4d739a1872bd84fbe68/chardet-4.0.0-py2.py3-none-any.whl.metadata
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: idna==3.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (3.9.1)
# Requirement already satisfied: numpy>=1.18.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Obtaining dependency information for opencv-python-headless==4.10.0.84 from https://files.pythonhosted.org/packages/1c/9b/583c8d9259f6fc19413f83fd18dd8e6cbc8eefb0b4dc6da52dd151fe3272/opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in /Users/user/Library/Python/3.12/lib/python/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Obtaining dependency information for python-dotenv from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /Users/user/Library/Python/3.12/lib/python/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Obtaining dependency information for requests-toolbelt from https://files.pythonhosted.org/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting python-magic (from roboflow)
#   Obtaining dependency information for python-magic from https://files.pythonhosted.org/packages/6c/73/9f872cb81fc5c3bb48f7227872c28975f998f3e7c2b1c16e95e6432bbb90/python_magic-0.4.27-py2.py3-none-any.whl.metadata
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /Users/user/Library/Python/3.12/lib/python/site-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.34-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 6.0 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 16.4 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 47.4 MB/s eta 0:00:0000:0100:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: python-magic, python-dotenv, opencv-python-headless, chardet, requests-toolbelt, roboflow
#   WARNING: The script dotenv is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script chardetect is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script roboflow is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed chardet-4.0.0 opencv-python-headless-4.10.0.84 python-dotenv-1.0.1 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.34
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show Roboflow
# Out:
# Name: roboflow
# Version: 1.1.34
# Summary: Official Python package for working with the Roboflow API
# Home-page: https://github.com/roboflow-ai/roboflow-python
# Author: Roboflow
# Author-email: support@roboflow.com
# License: UNKNOWN
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: certifi, chardet, cycler, idna, kiwisolver, matplotlib, numpy, opencv-python-headless, Pillow, python-dateutil, python-dotenv, python-magic, PyYAML, requests, requests-toolbelt, six, tqdm, urllib3
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="xy3XqA2VKRYeHqSjg5cv")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [00:05<00:00, 27928.61it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 3999.00it/s]

# %%
dataset.location
# Out:
# '/Users/user/football_ml/training/football_training_yolo_v5.ipynb/football-players-detection-1'

# %% [markdown]
# TRAINING

# %%
# %pip install yolov5
# Out:
# Collecting yolov5
#   Obtaining dependency information for yolov5 from https://files.pythonhosted.org/packages/1a/8d/ce2c22c4774fb5389d46921bea02f0efb8a409ec58f722949e96a62ef5c3/yolov5-7.0.13-py37.py38.py39.py310-none-any.whl.metadata
#   Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl.metadata (10 kB)
# Collecting gitpython>=3.1.30 (from yolov5)
#   Obtaining dependency information for gitpython>=3.1.30 from https://files.pythonhosted.org/packages/e9/bd/cc3a402a6439c15c3d4294333e13042b915bbeab54edc457c723931fed3f/GitPython-3.1.43-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib>=3.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (3.9.1)
# Requirement already satisfied: numpy>=1.18.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (10.4.0)
# Requirement already satisfied: psutil in /Users/user/Library/Python/3.12/lib/python/site-packages (from yolov5) (5.9.8)
# Requirement already satisfied: PyYAML>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (1.14.0)
# Collecting thop>=0.1.1 (from yolov5)
#   Obtaining dependency information for thop>=0.1.1 from https://files.pythonhosted.org/packages/bb/0f/72beeab4ff5221dc47127c80f8834b4bcd0cb36f6ba91c0b1d04a1233403/thop-0.1.1.post2209072238-py3-none-any.whl.metadata
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (2.3.1)
# Requirement already satisfied: torchvision>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (0.18.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (4.66.4)
# Requirement already satisfied: ultralytics>=8.0.100 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (8.2.54)
# Collecting tensorboard>=2.4.1 (from yolov5)
#   Obtaining dependency information for tensorboard>=2.4.1 from https://files.pythonhosted.org/packages/0a/32/2e8545fb0592f33e3aca5951e8b01008b76d61b440658cbdc37b4eaebf0b/tensorboard-2.17.0-py3-none-any.whl.metadata
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pandas>=1.1.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (0.13.2)
# Collecting setuptools>=65.5.1 (from yolov5)
#   Obtaining dependency information for setuptools>=65.5.1 from https://files.pythonhosted.org/packages/ef/15/88e46eb9387e905704b69849618e699dc2f54407d8953cc4ec4b8b46528d/setuptools-70.3.0-py3-none-any.whl.metadata
#   Downloading setuptools-70.3.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting fire (from yolov5)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 6.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting boto3>=1.19.1 (from yolov5)
#   Obtaining dependency information for boto3>=1.19.1 from https://files.pythonhosted.org/packages/cd/65/7cf1fd8f8073b1884fe7e559acb3fdd9957ba0cecd46e8bd4b2844b0a48a/boto3-1.34.143-py3-none-any.whl.metadata
#   Downloading boto3-1.34.143-py3-none-any.whl.metadata (6.6 kB)
# Collecting sahi>=0.11.10 (from yolov5)
#   Obtaining dependency information for sahi>=0.11.10 from https://files.pythonhosted.org/packages/2d/70/6f531d6074a37dd5e30b914ad5128bdcd0cb61db3d94bbf4a07c7ed5b4ec/sahi-0.11.18-py3-none-any.whl.metadata
#   Downloading sahi-0.11.18-py3-none-any.whl.metadata (17 kB)
# Collecting huggingface-hub>=0.12.0 (from yolov5)
#   Obtaining dependency information for huggingface-hub>=0.12.0 from https://files.pythonhosted.org/packages/69/d6/73f9d1b7c4da5f0544bc17680d0fa9932445423b90cd38e1ee77d001a4f5/huggingface_hub-0.23.4-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: roboflow>=0.2.29 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yolov5) (1.1.34)
# Collecting botocore<1.35.0,>=1.34.143 (from boto3>=1.19.1->yolov5)
#   Obtaining dependency information for botocore<1.35.0,>=1.34.143 from https://files.pythonhosted.org/packages/cf/15/359c52942418b5b9c094909174b9e97dd0364d1fc49fa588cab9361ae0fe/botocore-1.34.143-py3-none-any.whl.metadata
#   Downloading botocore-1.34.143-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.19.1->yolov5)
#   Obtaining dependency information for jmespath<2.0.0,>=0.7.1 from https://files.pythonhosted.org/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl.metadata
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.19.1->yolov5)
#   Obtaining dependency information for s3transfer<0.11.0,>=0.10.0 from https://files.pythonhosted.org/packages/3c/4a/b221409913760d26cf4498b7b1741d510c82d3ad38381984a3ddc135ec66/s3transfer-0.10.2-py3-none-any.whl.metadata
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->yolov5)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.12.0->yolov5) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.12.0->yolov5) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /Users/user/Library/Python/3.12/lib/python/site-packages (from huggingface-hub>=0.12.0->yolov5) (24.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.12.0->yolov5) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3->yolov5) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3->yolov5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3->yolov5) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3->yolov5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3->yolov5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/user/Library/Python/3.12/lib/python/site-packages (from matplotlib>=3.3->yolov5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.1.4->yolov5) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.1.4->yolov5) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->yolov5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->yolov5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->yolov5) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->yolov5) (2024.7.4)
# Requirement already satisfied: chardet==4.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow>=0.2.29->yolov5) (4.0.0)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow>=0.2.29->yolov5) (4.10.0.84)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow>=0.2.29->yolov5) (1.0.1)
# Requirement already satisfied: six in /Users/user/Library/Python/3.12/lib/python/site-packages (from roboflow>=0.2.29->yolov5) (1.16.0)
# Requirement already satisfied: requests-toolbelt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow>=0.2.29->yolov5) (1.0.0)
# Requirement already satisfied: python-magic in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from roboflow>=0.2.29->yolov5) (0.4.27)
# Collecting opencv-python>=4.1.1 (from yolov5)
#   Obtaining dependency information for opencv-python>=4.1.1 from https://files.pythonhosted.org/packages/77/df/b56175c3fb5bc058774bdcf35f5a71cf9c3c5b909f98a1c688eb71cd3b1f/opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting shapely>=1.8.0 (from sahi>=0.11.10->yolov5)
#   Obtaining dependency information for shapely>=1.8.0 from https://files.pythonhosted.org/packages/6a/6b/b6f4371346ad8ad513e8a8a01118cdae9e25510a01cc108f61321e59f8e3/shapely-2.0.4-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading shapely-2.0.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.0 kB)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5)
#   Obtaining dependency information for pybboxes==0.1.6 from https://files.pythonhosted.org/packages/3c/3f/46f6613b41a3c2b4f7af3b526035771ca5bb12d6fdf3b23145899f785e36/pybboxes-0.1.6-py3-none-any.whl.metadata
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting terminaltables (from sahi>=0.11.10->yolov5)
#   Obtaining dependency information for terminaltables from https://files.pythonhosted.org/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl.metadata
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting click (from sahi>=0.11.10->yolov5)
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.4.1->yolov5)
#   Obtaining dependency information for absl-py>=0.4 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.4.1->yolov5)
#   Obtaining dependency information for grpcio>=1.48.2 from https://files.pythonhosted.org/packages/85/72/235d6357fcc51fc325889278394f159dd3b935d904d526f4fd4832948f04/grpcio-1.65.0-cp312-cp312-macosx_10_9_universal2.whl.metadata
#   Downloading grpcio-1.65.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.4.1->yolov5)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/fc/b3/0c0c994fe49cd661084f8d5dc06562af53818cc0abefaca35bdc894577c3/Markdown-3.6-py3-none-any.whl.metadata
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,<5.0.0,>=3.19.6 (from tensorboard>=2.4.1->yolov5)
#   Obtaining dependency information for protobuf!=4.24.0,<5.0.0,>=3.19.6 from https://files.pythonhosted.org/packages/f3/bf/26deba06a4c910a85f78245cac7698f67cedd7efe00d04f6b3e1b3506a59/protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata
#   Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.4.1->yolov5)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/7a/13/e503968fefabd4c6b2650af21e110aa8466fe21432cd7c43a84577a89438/tensorboard_data_server-0.7.2-py3-none-any.whl.metadata
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.4.1->yolov5)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/9d/6e/e792999e816d19d7fcbfa94c730936750036d65656a76a5a688b57a656c4/werkzeug-3.0.3-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.7.0->yolov5) (1.13.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.7.0->yolov5) (3.3)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.7.0->yolov5) (3.1.4)
# Requirement already satisfied: py-cpuinfo in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics>=8.0.100->yolov5) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics>=8.0.100->yolov5) (2.0.0)
# Collecting termcolor (from fire->yolov5)
#   Obtaining dependency information for termcolor from https://files.pythonhosted.org/packages/d9/5f/8c716e47b3a50cbd7c146f45881e11d9414def768b7cd9c5e6650ec2a80a/termcolor-2.4.0-py3-none-any.whl.metadata
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->torch>=1.7.0->yolov5) (1.3.0)
# Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 18.0 MB/s eta 0:00:0000:01
# Downloading boto3-1.34.143-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 19.4 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 23.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 47.6 MB/s eta 0:00:00
# Downloading sahi-0.11.18-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 16.3 MB/s eta 0:00:00
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 54.4 MB/s eta 0:00:0000:0100:01
# Using cached setuptools-70.3.0-py3-none-any.whl (931 kB)
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 61.3 MB/s eta 0:00:0000:0100:01
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 19.4 MB/s eta 0:00:00
# Downloading botocore-1.34.143-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 64.2 MB/s eta 0:00:00a 0:00:01
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 11.8 MB/s eta 0:00:00
# Downloading grpcio-1.65.0-cp312-cp312-macosx_10_9_universal2.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 60.0 MB/s eta 0:00:00 0:00:01
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 14.0 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 36.5 MB/s eta 0:00:00
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 10.5 MB/s eta 0:00:00
# Downloading shapely-2.0.4-cp312-cp312-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.9 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 51.6 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (pyproject.toml) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=2717ece048afe3e07dfb5dff36037efdaa1d66da675144b2b4b22d9647379368
#   Stored in directory: /Users/user/Library/Caches/pip/wheels/97/4a/3f/f6f222440f03d888f026ac848b6b4ea57183ebfcd8f3cb8904
# Successfully built fire
# Installing collected packages: werkzeug, terminaltables, termcolor, tensorboard-data-server, smmap, shapely, setuptools, pybboxes, protobuf, opencv-python, markdown, jmespath, grpcio, click, absl-py, tensorboard, huggingface-hub, gitdb, fire, botocore, thop, sahi, s3transfer, gitpython, boto3, yolov5
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   WARNING: The script markdown_py is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script tensorboard is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script huggingface-cli is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script sahi is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script yolov5 is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed absl-py-2.1.0 boto3-1.34.143 botocore-1.34.143 click-8.1.7 fire-0.6.0 gitdb-4.0.11 gitpython-3.1.43 grpcio-1.65.0 huggingface-hub-0.23.4 jmespath-1.0.1 markdown-3.6 opencv-python-4.9.0.80 protobuf-4.25.3 pybboxes-0.1.6 s3transfer-0.10.2 sahi-0.11.18 setuptools-70.3.0 shapely-2.0.4 smmap-5.0.1 tensorboard-2.17.0 tensorboard-data-server-0.7.2 termcolor-2.4.0 terminaltables-3.1.10 thop-0.1.1.post2209072238 werkzeug-3.0.3 yolov5-7.0.13
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !yolo task = detect mode =train model=yolov5l.pt data ={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# zsh:1: train not found
